# %% [markdown]
# ###### Date of Implementation: 16/03/2026

# %% [markdown]
# ## 1. Import Reqd Libraries

# %%
import pandas as pd
import geopandas as gpd
import folium
from folium.plugins import HeatMap

# %% [markdown]
# ## 2. Load dataset

# %%
df = pd.read_csv('data/india_20_cities_dataset.csv')
gdf = gpd.read_file('data/india_states_simplified.geojson')

print(f"DataFrame top 5: \n{df.head()}")
print(f"\nDataFrame shape: {df.shape}")
print(f"\n\nGeoDataFrame top 5: \n{gdf.head()}")
print(f"\nGeoDataFrame shape: {gdf.shape}")
# Out:
# DataFrame top 5:
#         City        State  Latitude  Longitude  Cases  Population
# 0     Mumbai  Maharashtra   19.0760    72.8777   1500    20400000
# 1      Delhi        Delhi   28.7041    77.1025   1200    19000000
# 2    Kolkata  West Bengal   22.5726    88.3639    700    15000000
# 3  Bengaluru    Karnataka   12.9716    77.5946    800    12000000
# 4    Chennai   Tamil Nadu   13.0827    80.2707    600    11000000
#
# DataFrame shape: (20, 6)
#
#
# GeoDataFrame top 5:
#          state                                           geometry
# 0  Maharashtra  POLYGON ((71.4 17.5, 74.4 17.5, 74.4 20.5, 71....
# 1        Delhi  POLYGON ((75.6 27.2, 78.6 27.2, 78.6 30.2, 75....
# 2  West Bengal  POLYGON ((86.8 21.1, 89.8 21.1, 89.8 24.1, 86....
# 3    Karnataka  POLYGON ((76.1 11.5, 79.1 11.5, 79.1 14.5, 76....
# 4   Tamil Nadu  POLYGON ((78.7 11.6, 81.7 11.6, 81.7 14.6, 78....
#
# GeoDataFrame shape: (16, 2)

# %% [markdown]
# ## 3. Create base map

# %%
m = folium.Map(
    location=[20.5937, 78.9629],
    zoom_start=5
)

folium.GeoJson(gdf).add_to(m)

# %% [markdown]
# ## 4. Create marker map

# %%
for i, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['City'],
        tooltip=row['City']
    ).add_to(m)

# %% [markdown]
# ## 5. Create Choropleth Map

# %%
folium.Choropleth(
    geo_data=gdf,
    name='choropleth',
    data=df,
    columns=['State', 'Cases'],   # example columns
    key_on='feature.properties.state',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Cases by State'
).add_to(m)

# %% [markdown]
# ## 6. Add Multiple Dataset Layers

# %%
heat_data = [[row['Latitude'], row['Longitude']] for index, row in df.iterrows()]

HeatMap(heat_data).add_to(m)

# %% [markdown]
# ## 7. Display Map

# %%
m.save("output_map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6080067846c983961a108c374a86f04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6080067846c983961a108c374a86f04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6080067846c983961a108c374a86f04 = L.map(
#                 &quot;map_f6080067846c983961a108c374a86f04&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2614345ae477ee095e419336942f2405 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2614345ae477ee095e419336942f2405.addTo(map_f6080067846c983961a108c374a86f04);
#
#
#
#         function geo_json_90f486fd5741f863b720d3395bb3eeb8_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_90f486fd5741f863b720d3395bb3eeb8 = L.geoJson(null, {
#                 onEachFeature: geo_json_90f486fd5741f863b720d3395bb3eeb8_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_90f486fd5741f863b720d3395bb3eeb8_add (data) {
#             geo_json_90f486fd5741f863b720d3395bb3eeb8
#                 .addData(data);
#         }
#             geo_json_90f486fd5741f863b720d3395bb3eeb8_add({&quot;bbox&quot;: [71.1, 8.4, 93.2, 32.230000000000004], &quot;features&quot;: [{&quot;bbox&quot;: [71.4, 17.5, 74.4, 20.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.4, 17.5], [74.4, 17.5], [74.4, 20.5], [71.4, 20.5], [71.4, 17.5]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Maharashtra&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [75.6, 27.2, 78.6, 30.2], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[75.6, 27.2], [78.6, 27.2], [78.6, 30.2], [75.6, 30.2], [75.6, 27.2]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Delhi&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [86.8, 21.1, 89.8, 24.1], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[86.8, 21.1], [89.8, 21.1], [89.8, 24.1], [86.8, 24.1], [86.8, 21.1]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;West Bengal&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [76.1, 11.5, 79.1, 14.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[76.1, 11.5], [79.1, 11.5], [79.1, 14.5], [76.1, 14.5], [76.1, 11.5]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Karnataka&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [78.7, 11.6, 81.7, 14.6], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[78.7, 11.6], [81.7, 11.6], [81.7, 14.6], [78.7, 14.6], [78.7, 11.6]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Tamil Nadu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [77.0, 15.899999999999999, 80.0, 18.9], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[77.0, 15.899999999999999], [80.0, 15.899999999999999], [80.0, 18.9], [77.0, 18.9], [77.0, 15.899999999999999]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Telangana&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [71.1, 21.5, 74.1, 24.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.1, 21.5], [74.1, 21.5], [74.1, 24.5], [71.1, 24.5], [71.1, 21.5]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Gujarat&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [74.3, 25.4, 77.3, 28.4], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[74.3, 25.4], [77.3, 25.4], [77.3, 28.4], [74.3, 28.4], [74.3, 25.4]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;state&quot;: &quot;Rajasthan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [79.4, 25.3, 82.4, 28.3], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[79.4, 25.3], [82.4, 25.3], [82.4, 28.3], [79.4, 28.
